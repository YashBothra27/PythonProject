# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATA MANIPULATING AND CLEANING

# %% [markdown]
# DISPLAYING FIRST 10 ROWS FROM THE EXCEL FILE

# %%
data = pd.read_csv('vdogame.csv')
print(data.head(10))
# Out:
#     Rank                                   Name      Platform  Year   Genre  \
# 0   1587                                 Combat  Atarri  2600   NaN  Action
# 1   4234                           Circus Atari  Atarri  2600   NaN  Action
# 2   4380  Maze Craze: A Game of Cops 'n Robbers  Atarri  2600   NaN  Action
# 3   5800                           Slot Machine  Atarri  2600   NaN  Action
# 4   6318                           Flag Capture  Atarri  2600   NaN  Action
# 5   7371                        Ghostbusters II  Atarri  2600   NaN  Action
# 6   4793           LEGO Harry Potter: Years 5-7           3DS   NaN  Action
# 7  16496                             The Smurfs           3DS   NaN  Action
# 8   2840           LEGO Harry Potter: Years 5-7            DS   NaN  Action
# 9   5840                        Shrek the Third            DS   NaN  Action
#
#                                 Publisher  Global_Sales(mil)
# 0                                   Atari               1.25
# 1                                   Atari               0.46
# 2                                   Atari               0.45
# 3                                   Atari               0.31
# 4                                   Atari               0.27
# 5                              Activision               0.21
# 6  Warner Bros. Interactive Entertainment               0.40
# 7                                 Unknown               0.01
# 8  Warner Bros. Interactive Entertainment               0.72
# 9                              Activision               0.30

# %% [markdown]
# CREATING A DATAFRAME`

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Rank                                   Name      Platform    Year  \
# 0      1587                                 Combat  Atarri  2600     NaN
# 1      4234                           Circus Atari  Atarri  2600     NaN
# 2      4380  Maze Craze: A Game of Cops 'n Robbers  Atarri  2600     NaN
# 3      5800                           Slot Machine  Atarri  2600     NaN
# 4      6318                           Flag Capture  Atarri  2600     NaN
# ...     ...                                    ...           ...     ...
# 16589  6319                                 Bridge  Atarri  2600  1980.0
# 16590  6898                               Checkers  Atarri  2600  1980.0
# 16591   259                              Asteroids  Atarri  2600  1980.0
# 16592   545                        Missile Command  Atarri  2600  1980.0
# 16593  4027                             Ice Hockey  Atarri  2600  1980.0
#
#          Genre   Publisher  Global_Sales(mil)
# 0       Action       Atari               1.25
# 1       Action       Atari               0.46
# 2       Action       Atari               0.45
# 3       Action       Atari               0.31
# 4       Action       Atari               0.27
# ...        ...         ...                ...
# 16589     Misc  Activision               0.27
# 16590     Misc       Atari               0.24
# 16591  Shooter       Atari               4.31
# 16592  Shooter       Atari               2.76
# 16593   Sports  Activision               0.49
#
# [16594 rows x 7 columns]

# %% [markdown]
# GENERATING INFORMATION OF THE DATAFRAME

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16594 entries, 0 to 16593
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               16594 non-null  object
#  1   Name               16594 non-null  object
#  2   Platform           16594 non-null  object
#  3   Year               16330 non-null  float64
#  4   Genre              16594 non-null  object
#  5   Publisher          16536 non-null  object
#  6   Global_Sales(mil)  16594 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 907.6+ KB
# None

# %% [markdown]
# FILLING THE NULL VALUES

# %%
df = df.dropna(subset=['Year'])
df['Publisher'] = df['Publisher'].fillna('Unknown')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16330 entries, 264 to 16593
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               16330 non-null  object
#  1   Name               16330 non-null  object
#  2   Platform           16330 non-null  object
#  3   Year               16330 non-null  float64
#  4   Genre              16330 non-null  object
#  5   Publisher          16330 non-null  object
#  6   Global_Sales(mil)  16330 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 1020.6+ KB
# None

# %% [markdown]
# SORTING COLUMNS

# %%
multi_sort = df.sort_values(by=['Year', 'Name'], ascending=[True, False])
print(f'{multi_sort.head(5)}\n')
print(f'{multi_sort.tail(5)}')
# Out:
#        Rank             Name      Platform    Year    Genre   Publisher  \
# 16592   545  Missile Command  Atarri  2600  1980.0  Shooter       Atari
# 16587  1768          Kaboom!  Atarri  2600  1980.0     Misc  Activision
# 16593  4027       Ice Hockey  Atarri  2600  1980.0   Sports  Activision
# 16585  5368          Freeway  Atarri  2600  1980.0   Action  Activision
# 16588  1971         Defender  Atarri  2600  1980.0     Misc       Atari
#
#        Global_Sales(mil)
# 16592               2.76
# 16587               1.15
# 16593               0.49
# 16585               0.34
# 16588               1.05
#
#       Rank                    Name Platform    Year      Genre  \
# 383   6392          Ace Attorney 6      3DS  2016.0  Adventure
# 305   9880           7 Days to Die      PS4  2016.0     Action
# 374  13652           7 Days to Die     XOne  2016.0     Action
# 434  14779  3DS Classic Collection      3DS  2016.0       Misc
# 386  14007   12-Sai. Koisuru Diary      3DS  2016.0  Adventure
#
#           Publisher  Global_Sales(mil)
# 383          Capcom               0.27
# 305  Telltale Games               0.12
# 374  Telltale Games               0.04
# 434            Sega               0.03
# 386        Happinet               0.04

# %%
platform_count = df['Platform'].value_counts()
print(f'Total number of platforms: {len(platform_count)}\n')
print(f'Platform with Most games:{platform_count.head(5)}\n')
print(f'Platform with Least games:{platform_count.tail(5)}\n')
# Out:
# Total number of platforms: 31
#
# Platform with Most games:Platform
# DS      2132
# PS2     2130
# PS3     1304
# Wii     1291
# X360    1235
# Name: count, dtype: int64
#
# Platform with Least games:Platform
# SCD     6
# 3DO     3
# TG16    2
# PCFX    1
# GG      1
# Name: count, dtype: int64

# %%
year_count = df['Year'].value_counts()
print(f'Total number of years: {len(year_count)}\n')
print(f'Year with Most games launched:{year_count.head(5)}\n')
print(f'Year with Least games launched:{year_count.tail(5)}')
# Out:
# Total number of years: 37
#
# Year with Most games launched:Year
# 2009.0    1431
# 2008.0    1429
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# Name: count, dtype: int64
#
# Year with Least games launched:Year
# 1990.0    16
# 1988.0    15
# 1985.0    14
# 1984.0    14
# 1980.0     9
# Name: count, dtype: int64

# %%
genre_count = df['Genre'].value_counts()
print(f'Total number of genres: {len(genre_count)}\n')
print(f'Genre with Most games:{genre_count.head(5)}\n')
print(f'Genre with Least games:{genre_count.tail(5)}')
# Out:
# Total number of genres: 12
#
# Genre with Most games:Genre
# Action          3254
# Sports          2307
# Misc            1710
# Role-Playing    1469
# Shooter         1283
# Name: count, dtype: int64
#
# Genre with Least games:Genre
# Platform      876
# Simulation    850
# Fighting      837
# Strategy      671
# Puzzle        571
# Name: count, dtype: int64

# %%
publisher_count = df['Publisher'].value_counts()
print(f'Total number of platforms: {len(publisher_count)}\n')
print(f'Publisher with Most games:{publisher_count.head(5)}\n')
print(f'Publisher with Least games:{publisher_count.tail(5)}')
# Out:
# Total number of platforms: 576
#
# Publisher with Most games:Publisher
# Electronic Arts                 1341
# Activision                       967
# Namco Bandai Games               928
# Ubisoft                          917
# Konami Digital Entertainment     824
# Name: count, dtype: int64
#
# Publisher with Least games:Publisher
# EA Games                 1
# Image Epoch              1
# Introversion Software    1
# Piacci                   1
# Boost On                 1
# Name: count, dtype: int64

# %% [markdown]
# ## DATA VISUALIZATION USING MATPLOTLIB

# %% [markdown]
# NUMBER OF GAME RELEASED BY GENRE(BAR PLOT)

# %%
plt.figure(figsize=(12, 8))
plt.pie(genre_count,labels=genre_count.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of Genres',fontsize=16)
plt.legend(genre_count.index, loc='upper left')
plt.show()

# %% [markdown]
# GAMES RELEASED EVERY YEAR(BAR PLOT)

# %%
plt.figure(figsize=(10, 6))
plt.bar(year_count.index, year_count.values, color='skyblue')
plt.xlabel('Year',fontsize=12)
plt.ylabel('Number of Games',fontsize=12)
plt.title('Number of Games Released by Year',fontsize=16)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# NUMBER OF GAME RELEASED IN EACH PLATFORM(Bar Plot)

# %%
platform_games = data['Platform'].value_counts()
plt.figure(figsize=(12, 7))
plt.bar(platform_games.index, platform_games.values, color='purple')
plt.xlabel('Platform', fontsize=12)
plt.ylabel('Number of Games', fontsize=12)
plt.title('Number of Games Released in each platform', fontsize=16)
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %% [markdown]
# TOTAL GLOBAL SALES(LINE PLOT)

# %%
sales_yearly = data.groupby('Year')['Global_Sales(mil)'].sum()

plt.figure(figsize=(10, 6))
plt.plot(sales_yearly.index, sales_yearly.values, marker='o', linestyle='-', color='green')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Global Sales (Million)', fontsize=12)
plt.title('Total Global Sales of Video Games every Year', fontsize=16)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# GLOBAL SALES BY GENRE(HORIZONTAL BAR PLOT)

# %%
sales_by_genre = df.groupby('Genre')['Global_Sales(mil)'].sum().sort_values(ascending=False)

# Plot
plt.figure(figsize=(12, 7))
plt.barh(sales_by_genre.index, sales_by_genre.values, color='red')
plt.xlabel('Global sales(millions)',fontsize=12)
plt.ylabel('Genre',fontsize=12)
plt.title('Total Global Sales by Genre',fontsize=16)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# GLOBAL SALES BY PUBLISHER(pie chart)

# %%
top_publishers = df.groupby('Publisher')['Global_Sales(mil)'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,7))
plt.pie(top_publishers, labels=top_publishers.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Top 10 Publishers by Global Sales', fontsize=16)
plt.legend(top_publishers.index, loc='lower left')
plt.show()

# %% [markdown]
# ## PIVOT TABLE

# %% [markdown]
# PIVOT TABLE: SALES BY GENRE PER YEAR

# %%
sales_by_genre_year = df.pivot_table(index='Year', columns='Genre',values='Global_Sales(mil)', aggfunc='sum', fill_value=0)
print(f'pivot table:\n{sales_by_genre_year}')
# Out:
# pivot table:
# Genre   Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# Year
# 1980.0    0.34       0.00      0.77   2.71      0.00    0.00    0.00
# 1981.0   14.84       0.00      0.00   0.00      6.93    2.24    0.48
# 1982.0    6.52       0.00      0.00   0.87      5.03   10.03    1.57
# 1983.0    2.86       0.40      0.00   2.14      6.93    0.78    0.00
# 1984.0    1.85       0.00      0.00   1.45      0.69    3.14    5.95
# 1985.0    3.52       0.00      1.05   0.00     43.17    3.21    0.00
# 1986.0   13.74       0.00      0.00   0.00      9.39    0.00    1.96
# 1987.0    1.12       4.38      5.42   0.00      1.74    0.00    0.00
# 1988.0    1.75       0.00      0.00   0.00     27.73    5.58    2.14
# 1989.0    4.64       0.00      0.00   1.28     20.66   37.75    0.00
# 1990.0    6.39       0.00      0.00   0.00     22.97    6.00    6.26
# 1991.0    6.76       2.24      0.39   0.08      7.64    3.24    1.14
# 1992.0    3.83      12.24     15.25   4.94     13.42    4.84    9.04
# 1993.0    1.81       0.07      8.75   0.30     18.67    3.17    0.36
# 1994.0    1.55       3.74      8.47   2.86     28.74    1.53    2.19
# 1995.0    3.57       0.72     14.85   6.40     16.69    2.71    6.09
# 1996.0   20.58       4.19     18.06  10.68     28.23    3.91   28.24
# 1997.0   27.58       4.96     11.76   5.69     21.85    5.89   31.91
# 1998.0   39.44       9.05     31.66  11.94     29.88    6.34   27.90
# 1999.0   27.78       7.60     14.26  20.65     20.82    1.36   37.27
# 2000.0   34.18       2.98     20.22  15.54     16.06    3.82   19.99
# 2001.0   59.39       9.12     18.12  16.40     39.28    8.00   55.81
# 2002.0   86.77      11.05     25.02  15.67     45.97    5.34   30.20
# 2003.0   67.93       2.14     23.73  23.82     42.89    2.42   52.19
# 2004.0   76.26       8.70     16.78  31.32     47.34    8.43   47.86
# 2005.0   85.69       8.53     22.72  61.24     23.56   20.45   56.42
# 2006.0   66.58      11.47     22.55  67.35     49.80   10.90   34.09
# 2007.0  106.50      24.47     17.61  92.27     35.59   24.00   39.17
# 2008.0  136.39      25.02     35.38  87.03     35.70   15.59   70.66
# 2009.0  139.36      20.68     32.15  76.94     41.09   20.31   34.19
# 2010.0  117.64      16.57     14.89  96.86     31.90   11.18   34.93
# 2011.0  118.96      15.98     22.68  56.08     28.11    5.11   35.01
# 2012.0  122.04       5.99      9.51  22.92     18.55    1.76   14.46
# 2013.0  125.58       6.61      7.21  25.65     25.12    0.99   13.04
# 2014.0   99.02       6.06     16.15  23.68      8.89    1.50   16.69
# 2015.0   70.70       8.03      7.78  11.69      6.05    0.70    7.92
# 2016.0   19.91       1.81      3.86   1.17      2.07    0.00    1.64
#
# Genre   Role-Playing  Shooter  Simulation  Sports  Strategy
# Year
# 1980.0          0.00     7.07        0.00    0.49      0.00
# 1981.0          0.00    10.04        0.45    0.79      0.00
# 1982.0          0.00     3.79        0.00    1.05      0.00
# 1983.0          0.00     0.48        0.00    3.20      0.00
# 1984.0          0.00    31.10        0.00    6.18      0.00
# 1985.0          0.00     1.00        0.03    1.96      0.00
# 1986.0          2.52     3.89        0.00    5.57      0.00
# 1987.0          4.65     0.71        0.00    3.72      0.00
# 1988.0          5.88     0.51        0.03    3.60      0.00
# 1989.0          2.20     1.20        0.00    5.72      0.00
# 1990.0          4.52     0.00        1.14    2.11      0.00
# 1991.0          3.25     2.00        2.14    2.41      0.94
# 1992.0          6.86     0.29        2.14    2.95      0.36
# 1993.0          5.59     3.08        0.19    3.18      0.81
# 1994.0          7.11     8.30        2.73    8.39      3.56
# 1995.0         14.26     4.15        4.18    7.98      6.51
# 1996.0         43.96     6.91       11.33   17.45      5.61
# 1997.0         21.79    22.17        9.65   30.02      7.71
# 1998.0         28.09     9.80        7.11   41.79     13.47
# 1999.0         49.09    12.25       11.44   30.29     18.46
# 2000.0         29.03     6.81        3.38   41.19      8.50
# 2001.0         22.06    24.77       19.54   51.43      7.55
# 2002.0         45.13    48.58       10.81   65.42      5.56
# 2003.0         30.28    27.14       21.21   64.83      7.99
# 2004.0         53.95    46.95       10.85   63.68      7.19
# 2005.0         28.55    41.60       49.27   59.54      5.37
# 2006.0         57.73    40.63       21.77  136.16      4.27
# 2007.0         43.89    71.04       48.97   98.20      9.42
# 2008.0         59.83    59.51       46.76   96.14     11.69
# 2009.0         47.90    69.89       33.71  138.52     12.56
# 2010.0         70.52    77.41       22.15   92.53     13.87
# 2011.0         53.37    99.36       15.28   56.99      9.06
# 2012.0         47.81    72.86       13.38   30.93      3.33
# 2013.0         44.92    62.80        8.67   41.55      6.33
# 2014.0         45.86    66.00        5.55   46.66      0.99
# 2015.0         36.44    66.15        5.62   41.54      1.82
# 2016.0          6.76    18.22        0.39   14.60      0.50

# %% [markdown]
# PIVOT TABLE: Average Sales per Genre on Top Platforms

# %%
avg_sales_platform = df.pivot_table(index='Platform', columns='Genre', values='Global_Sales(mil)', aggfunc='mean', fill_value=0)
print(f'avg_sales_platform : \n{avg_sales_platform}')
# Out:
# avg_sales_platform :
# Genre           Action  Adventure  Fighting      Misc  Platform    Puzzle  \
# Platform
# 3DO           0.000000   0.060000  0.000000  0.000000  0.000000  0.020000
# 3DS           0.314500   0.131389  0.747143  0.197736  1.151071  0.278500
# Atarri  2600  0.479818   0.400000  0.770000  0.716000  1.474444  1.706250
# DC            0.420000   0.227273  0.152500  0.000000  1.270000  0.000000
# DS            0.339851   0.198109  0.200000  0.353907  0.860222  0.355381
# GB            1.320000   3.432000  0.000000  1.668750  2.993333  3.164667
# GBA           0.334938   0.332162  0.183043  0.329545  0.561727  0.310000
# GC            0.380102   0.296500  0.438810  0.470000  0.392603  0.380833
# GEN           0.913333   0.095000  1.180000  0.030000  2.207143  0.000000
# GG            0.000000   0.000000  0.000000  0.000000  0.040000  0.000000
# N64           0.778421   0.112500  0.761379  0.621667  1.204333  0.284167
# NES           2.211538   4.380000  1.635000  1.795000  3.420714  1.500000
# NG            0.000000   0.000000  0.129091  0.000000  0.000000  0.000000
# PC            0.191543   0.155231  0.028000  0.382273  0.044545  0.036800
# PCFX          0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# PS            0.816494   0.310000  0.672963  0.590789  1.003281  0.377500
# PS2           0.789652   0.107959  0.627143  0.452706  0.713960  0.327778
# PS3           0.815067   0.317639  0.680263  0.379421  0.829167  0.230000
# PS4           0.713607   0.247368  0.472941  0.493333  0.637273  0.020000
# PSP           0.288756   0.050188  0.299726  0.131731  0.480000  0.125455
# PSV           0.141844   0.048605  0.196875  0.215833  0.303000  0.066667
# SAT           0.216667   0.160000  0.274839  0.080000  0.152000  0.200000
# SCD           0.000000   0.000000  0.000000  0.050000  1.500000  0.000000
# SNES          0.840000   0.375000  1.078000  0.295294  2.525000  0.490769
# TG16          0.000000   0.140000  0.000000  0.000000  0.000000  0.000000
# WS            0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# Wii           0.480348   0.220843  0.580976  0.799375  1.590877  0.289444
# WiiU          0.307143   0.056667  1.272000  0.582381  1.327500  0.332500
# X360          0.753679   0.324043  0.579077  0.732213  0.474583  0.118333
# XB            0.312237   0.117692  0.291591  0.192667  0.197143  0.060000
# XOne          0.496912   0.209167  0.330000  0.457333  0.202500  0.000000
#
# Genre           Racing  Role-Playing   Shooter  Simulation    Sports  Strategy
# Platform
# 3DO           0.000000      0.000000  0.000000    0.020000  0.000000  0.000000
# 3DS           1.441000      0.890706  0.203333    0.949643  0.247200  0.139333
# Atarri  2600  0.580000      0.000000  1.044091    0.450000  0.277000  0.000000
# DC            0.441667      0.170000  0.110000    0.520000  0.366000  0.000000
# DS            0.584545      0.645714  0.195238    0.470824  0.217192  0.189231
# GB            2.275000      4.201905  1.200000    0.710000  1.005556  1.150000
# GBA           0.293750      0.879589  0.090000    0.328333  0.186477  0.413889
# GC            0.363167      0.521200  0.283958    0.715833  0.231038  0.392727
# GEN           0.260000      0.090000  0.130000    0.000000  1.066667  0.190000
# GG            0.000000      0.000000  0.000000    0.000000  0.000000  0.000000
# N64           0.703333      0.432857  0.802917    1.019000  0.412658  1.147778
# NES           2.445000      1.707273  5.088571    0.000000  1.917857  0.000000
# NG            0.000000      0.000000  0.000000    0.000000  0.020000  0.000000
# PC            0.066842      0.459903  0.299586    0.451391  0.245102  0.247514
# PCFX          0.000000      0.030000  0.000000    0.000000  0.000000  0.000000
# PS            0.714514      0.807216  0.409479    0.422167  0.540769  0.309571
# PS2           0.727406      0.500273  0.685316    0.474831  0.690483  0.214857
# PS3           0.812222      0.643077  1.263226    0.357333  0.642429  0.216818
# PS4           0.678235      0.559565  2.215294    0.154000  1.164419  0.082000
# PSP           0.534308      0.256597  0.534324    0.216552  0.310687  0.177414
# PSV           0.268182      0.161481  0.914000    0.026667  0.212174  0.044286
# SAT           0.300000      0.221176  0.180909    0.161429  0.174375  0.180000
# SCD           0.070000      0.060000  0.000000    0.000000  0.000000  0.140000
# SNES          1.498889      0.728600  0.607000    0.625556  0.364694  0.332000
# TG16          0.000000      0.000000  0.020000    0.000000  0.000000  0.000000
# WS            0.000000      0.305000  0.000000    0.000000  0.000000  0.100000
# Wii           0.665652      0.401714  0.461290    0.435952  1.132617  0.209200
# WiiU          2.590000      0.411667  0.617000    0.210000  0.415000  0.413333
# X360          0.638529      0.947105  1.407259    0.391667  0.639209  0.361852
# XB            0.257541      0.587391  0.500968    0.296250  0.319578  0.132381
# XOne          0.463158      0.729231  1.563939    0.180000  0.665833  0.126667
